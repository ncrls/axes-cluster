# %% [markdown]
# # Agglomerative clustering using hclust

# %%
# libraries
library(conflicted)
library(tidyverse)  # data manipulation
library(cluster)    # clustering algorithms
library(factoextra) # clustering visualization
library(dendextend) # for comparing two dendrograms
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# Welcome to factoextra!
#
# Want to learn more? See two factoextra-related books at https://www.datanovia.com/en/product/practical-guide-to-principal-component-methods-in-r/
#
#
# ---------------------
# Welcome to dendextend version 1.19.1
# Type citation('dendextend') for how to cite the package.
#
# Type browseVignettes(package = 'dendextend') for the package vignette.
# The github page is: https://github.com/talgalili/dendextend/
#
# Suggestions and bug-reports can be submitted at: https://github.com/talgalili/dendextend/issues
# You may ask questions at stackoverflow, use the r and dendextend tags:
# 	 https://stackoverflow.com/questions/tagged/dendextend
#
# 	To suppress this message use:  suppressPackageStartupMessages(library(dendextend))
# ---------------------

# %%
grades <- read.csv("axes_measure_1.csv")
grades %>% head()
# Out:
#   X длина_1    длина_2     длина_целого высота_обуха ширина      обух_ширина
# 1 0  0.1184773 -0.07371231 -0.001689074 -0.8847459    0.63094326  0.2041899
# 2 1  0.2563212 -1.35441641 -0.902337679 -0.8847459   -1.01628391 -1.4244272
# 3 2 -0.9153514  2.12178043  1.141441848 -0.8847459    0.43715183  2.2613905
# 4 3 -1.4667268 -0.66832493 -1.248740989 -0.8847459   -1.59765820 -0.3958269
# 5 4  0.5320089 -0.80554322 -0.348092384 -0.8847459   -0.14422247 -0.1386769
# 6 5  0.2563212 -0.89702209 -0.555934370 -0.8847459    0.07863768  0.4013383
#   диаметр    сечение_1  сечение_2  сечение_3
# 1  0.7541146 -0.1353587  0.4423863  0.3217663
# 2 -0.5721625 -0.9377301 -0.7876882 -1.0626385
# 3  1.0193700  1.3690877  1.0574235  0.7477370
# 4 -0.5721625 -0.6368409 -0.6851820 -0.3171898
# 5 -1.6331841 -0.4362480 -0.2751571  0.5347517
# 6  0.2236037  1.2687912  1.2316840  1.1311107

# %%
# dissimilarity matrix
dissim_grades_norm <- dist(grades, method = "euclidian")

# hierarchical clustering using hclust (complete linkage)
hcl_grades_norm <- hclust(dissim_grades_norm, method = "complete")

# Plot the dendogram
plot(hcl_grades_norm, cex = 0.6, hang = 0.3, xlab = "respondents")
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# # Aglomerative Nesting clustering (Agnes)

# %%
acl_grades_norm <- agnes(grades, method = "ward")
pltree(acl_grades_norm, cex = 0.6, hang = .3, main = "Dendogram using AGNES" )
# Out:
# Plot with title “Dendogram using AGNES”

# %% [markdown]
# # Divisive hierarchical clustering (Diana)

# %%
dcl_grades <- diana(grades)
pltree(dcl_grades, cex = 0.6, hang = 0.3, main = "Dendrogram of Diana")
# Out:
# Plot with title “Dendrogram of Diana”
